# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)
plt.xlabel("month")
plt.ylabel("savings in $")
plt.title("savings acct results")

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt() object oriented
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)
plt.grid()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=3, label='Boston')


# Create labels for the x and y axes.x
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45.
plt.ylim(0, 45)

# Create a title.
plt.title("PyBer Fare by Month")

# Add the legend.
plt.legend()

# Add grid
plt.grid()

# %%
# Create the plot with ax.plt() object oriented

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot()


ax.plot(x_axis, y_axis, marker="D", color="green", ls="--", lw=2, label = "Boston")
ax.set_ylim(0, 45)
ax.set_title("PyBer Fare by Month")
ax.set_ylabel('fare($)')
ax.set_xlabel("Month")
ax.legend()
ax.grid()
ax.marker="D"

plt.savefig("test.PNG")

# %%
plt.bar(x_axis, y_axis, color="green", label="boston")

# %%
plt.barh(x_axis, y_axis, color="cyan", label="boston")

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label="boston")
ax.set_ylabel('fare($)')
ax.set_xlabel("Month")

data:image/png;base64,...

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()

# set multiplier for marker size
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*5)

# create scatter plot
ax.scatter(y_axis, x_axis, s=y_axis_larger, c="red",  edgecolors="black", alpha=0.80, linewidth=3, marker="o", label="boston")

ax.legend()
ax.set_xlabel("Month")
ax.set_ylabel('fare($)')
ax.set_title("fares by month")
ax.invert_yaxis()

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0.2, 0.2, 0.3, 0.2, 0.2, 0.2, 0.2, 0.3, 0.16, 0.2, 0.2, 0.2)
plt.pie(y_axis, 
        explode=explode_values,
        colors=colors,
        labels=x_axis, 
        autopct='%.1f%%')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
import numpy as np
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
plt.show()
